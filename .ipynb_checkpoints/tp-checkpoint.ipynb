# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
d1 = pd.read_csv("./data/price_availability.csv", delimiter=";");
d2 = pd.read_csv("./data/listings_final.csv", delimiter=";");

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4748696 entries, 0 to 4748695
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   day             object
#  2   created         object
#  3   available       bool
#  4   local_currency  object
#  5   local_price     int64
#  6   min_nights      int64
# dtypes: bool(1), int64(3), object(3)
# memory usage: 221.9+ MB

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1000 non-null   int64
#  1   listing_id                1000 non-null   int64
#  2   name                      1000 non-null   object
#  3   type                      1000 non-null   object
#  4   city                      1000 non-null   object
#  5   neighborhood              935 non-null    object
#  6   latitude                  1000 non-null   float64
#  7   longitude                 1000 non-null   float64
#  8   person_capacity           1000 non-null   int64
#  9   beds                      1000 non-null   int64
#  10  bedrooms                  1000 non-null   int64
#  11  bathrooms                 1000 non-null   float64
#  12  is_rebookable             1000 non-null   bool
#  13  is_new_listing            1000 non-null   bool
#  14  is_fully_refundable       1000 non-null   bool
#  15  is_host_highly_rated      1000 non-null   bool
#  16  is_business_travel_ready  1000 non-null   bool
#  17  pricing_weekly_factor     1000 non-null   float64
#  18  pricing_monthly_factor    1000 non-null   float64
# dtypes: bool(5), float64(5), int64(5), object(4)
# memory usage: 114.4+ KB

# %%
from sklearn.model_selection import train_test_split

# %%
g = d1.groupby('listing_id');

# on ajoute une nouvelle colonne dans le DataFrame qui contient toutes les infos

d2['price_avg'] = 0

# on fait un boucle sur les lignes du DataFrame qui contient toutes les infos (i = index, x = data)

for (i,x) in d2.iterrows():
    #on vérifie que le listing_id possède bien des historiques de prix en regardant si la valeur de listing_id est bien une clé du tableau d'historique g
    if x.listing_id in g.groups.keys():
        # on ajoute pour la ligne i (qui correspond à la ligne) et pour la colonne price_avg la moyenne de tous les historiques de prix
        d2.loc[i,'price_avg'] = g.get_group(x.listing_id).local_price.mean()
d2
# Out:
#      Unnamed: 0  listing_id                                      name  \
# 0             0    28581061                           La maison Clery
# 1             1      661961       studio PARIS PLACE EDITH PIAF 75020
# 2             2     1261705  chambre privée à louer @ paris oberkampf
# 3             3     1318834            Appartement au coeur du Marais
# 4             4     1677091                       Lovely & Quiet flat
# ..          ...         ...                                       ...
# 995         995    28335197          Studio cosy Jardin du Luxembourg
# 996         996    28583013    Charmant  30m2 - Faubourg Saint Martin
# 997         997    28628316       Cosy flat in the marais - Best area
# 998         998    28792796         Appartement 3 chambres madeleine.
# 999         999    28682896                          Village Jourdain
#
#              type   city                    neighborhood   latitude  \
# 0    private_room  Paris               2e arrondissement  48.869292
# 1     entire_home  Paris                             NaN  48.867284
# 2    private_room  Paris                             NaN  48.867894
# 3     entire_home  Paris                      République  48.870370
# 4     entire_home  Paris    Buttes-Chaumont - Belleville  48.874149
# ..            ...    ...                             ...        ...
# 995   entire_home  Paris  Saint Germain des Prés - Odéon  48.848695
# 996   entire_home  Paris                      République  48.871623
# 997   entire_home  Paris               2e arrondissement  48.867434
# 998   entire_home  Paris             Madeleine - Vendôme  48.870109
# 999  private_room  Paris    Buttes-Chaumont - Belleville  48.875425
#
#      longitude  person_capacity  beds  bedrooms  bathrooms  is_rebookable  \
# 0     2.348335                1     1         1        2.0          False
# 1     2.403255                2     1         1        1.0          False
# 2     2.375897                1     1         1        1.0          False
# 3     2.358510                3     2         2        1.0          False
# 4     2.373700                2     1         1        1.0          False
# ..         ...              ...   ...       ...        ...            ...
# 995   2.325857                2     1         0        1.0          False
# 996   2.358006                3     1         1        1.0          False
# 997   2.351771                4     2         1        1.0          False
# 998   2.321475                6     4         2        1.5          False
# 999   2.395240                2     1         1        1.0          False
#
#      is_new_listing  is_fully_refundable  is_host_highly_rated  \
# 0              True                 True                 False
# 1             False                 True                  True
# 2             False                 True                  True
# 3             False                 True                 False
# 4             False                 True                  True
# ..              ...                  ...                   ...
# 995            True                 True                 False
# 996            True                 True                 False
# 997            True                 True                  True
# 998            True                 True                 False
# 999            True                 True                 False
#
#      is_business_travel_ready  pricing_weekly_factor  pricing_monthly_factor  \
# 0                       False                   1.00                    1.00
# 1                       False                   0.88                    0.69
# 2                       False                   1.00                    1.00
# 3                       False                   0.82                    0.48
# 4                       False                   0.95                    0.90
# ..                        ...                    ...                     ...
# 995                     False                   0.79                    1.00
# 996                     False                   1.00                    1.00
# 997                     False                   1.00                    1.00
# 998                     False                   1.00                    1.00
# 999                     False                   1.00                    1.00
#
#       price_avg
# 0     45.948454
# 1     44.473684
# 2     49.000000
# 3    165.000000
# 4     69.774436
# ..          ...
# 995   38.507732
# 996  147.752551
# 997  152.860825
# 998   49.184211
# 999   39.503937
#
# [1000 rows x 20 columns]

# %%
# variables prédictives et cible
X=d2
y=d2['price_avg']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 541 to 102
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                700 non-null    int64
#  1   listing_id                700 non-null    int64
#  2   name                      700 non-null    object
#  3   type                      700 non-null    object
#  4   city                      700 non-null    object
#  5   neighborhood              649 non-null    object
#  6   latitude                  700 non-null    float64
#  7   longitude                 700 non-null    float64
#  8   person_capacity           700 non-null    int64
#  9   beds                      700 non-null    int64
#  10  bedrooms                  700 non-null    int64
#  11  bathrooms                 700 non-null    float64
#  12  is_rebookable             700 non-null    bool
#  13  is_new_listing            700 non-null    bool
#  14  is_fully_refundable       700 non-null    bool
#  15  is_host_highly_rated      700 non-null    bool
#  16  is_business_travel_ready  700 non-null    bool
#  17  pricing_weekly_factor     700 non-null    float64
#  18  pricing_monthly_factor    700 non-null    float64
#  19  price_avg                 700 non-null    float64
# dtypes: bool(5), float64(6), int64(5), object(4)
# memory usage: 90.9+ KB

# %%
X_train2 = X_train[['listing_id', 'latitude','longitude', 'person_capacity', 'beds', 'bedrooms','bathrooms', 'is_rebookable', 'is_new_listing', 'is_fully_refundable','is_host_highly_rated','is_business_travel_ready','pricing_weekly_factor','pricing_monthly_factor','price_avg']]
X_train2
# Out:
#      listing_id   latitude  longitude  person_capacity  beds  bedrooms  \
# 541    17861418  48.864368   2.365046                5     2         1
# 440    14602664  48.852479   2.370040                3     2         0
# 482    16021853  48.863601   2.378555                2     1         0
# 422    13906730  48.850560   2.343260                6     2         2
# 778    24239065  48.849364   2.336585                2     1         1
# ..          ...        ...        ...              ...   ...       ...
# 106     1205915  48.860755   2.364236                6     3         3
# 270     6332449  48.872093   2.342469                2     1         0
# 860    25996329  48.861990   2.361379                2     1         0
# 435    14433920  48.865297   2.362245                4     2         0
# 102     1128202  48.849406   2.310849                5     4         3
#
#      bathrooms  is_rebookable  is_new_listing  is_fully_refundable  \
# 541        1.0          False           False                 True
# 440        1.0          False           False                 True
# 482        1.0          False           False                 True
# 422        1.0          False           False                 True
# 778        1.0          False           False                 True
# ..         ...            ...             ...                  ...
# 106        1.5          False           False                 True
# 270        1.0          False           False                False
# 860        1.0          False           False                 True
# 435        1.0          False           False                 True
# 102        2.0          False           False                 True
#
#      is_host_highly_rated  is_business_travel_ready  pricing_weekly_factor  \
# 541                 False                     False                   0.95
# 440                 False                     False                   1.00
# 482                 False                     False                   0.90
# 422                  True                     False                   0.98
# 778                  True                     False                   1.00
# ..                    ...                       ...                    ...
# 106                  True                     False                   0.97
# 270                  True                     False                   1.00
# 860                  True                     False                   1.00
# 435                  True                     False                   1.00
# 102                  True                     False                   0.71
#
#      pricing_monthly_factor   price_avg
# 541                    0.90  161.550388
# 440                    1.00   52.891262
# 482                    0.85   38.511719
# 422                    0.75  204.960938
# 778                    1.00  207.553640
# ..                      ...         ...
# 106                    0.85  315.487179
# 270                    1.00  118.784736
# 860                    1.00  103.561039
# 435                    1.00  127.000000
# 102                    0.58  180.000000
#
# [700 rows x 15 columns]

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train2,y_train)

# %%
reg.score(X_train2, y_train)
# Out:
# 1.0

# %%
reg.coef_
# Out:
# array([ 6.57664454e-16, -9.06275055e-13, -6.02618067e-13,  3.61924032e-14,
#        -2.03274897e-14,  2.34864211e-14,  3.85935045e-14,  4.06575815e-20,
#         8.71438338e-15, -3.57745517e-14, -9.37531303e-15,  5.08219768e-21,
#         9.14199272e-15, -1.36826314e-15,  1.00000000e+00])

# %%
reg.intercept_
# Out:
# -1.0148511364604929e-08
